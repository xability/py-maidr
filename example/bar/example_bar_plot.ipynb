# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns

# Load dataset
tips = sns.load_dataset("tips")

# Create a bar plot
cut_counts = tips["day"].value_counts()
plt.figure(figsize=(10, 6))
b_plot = plt.bar(cut_counts.index, list(cut_counts.values), color="skyblue")
plt.title("The Number of Tips by Day")
plt.xlabel("Day")
plt.ylabel("Count")

# plt.show()
maidr.show(b_plot)
# Out:
# <iframe id="iframe_764ea9ee-dfc0-455b-9ac3-6057390dc368" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; id=&quot;facba1dd-c705-4d5e-b17c-ba590cce422d&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;9a18c5e9-91f5-4015-978d-118863bf81da&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;861db798-099e-4744-95cf-848fcddb1b0d&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;bar&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;The Number of Tips by Day&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Day&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Count&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Sat&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 87.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Sun&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 76.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Thur&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 62.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Fri&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 19.0&amp;#10;              }&amp;#10;            ],&amp;#10;            &amp;quot;selectors&amp;quot;: &amp;quot;path[maidr=&apos;a4e5e768-2271-455f-b52a-8aecf0468b77&apos;]&amp;quot;,&amp;#10;            &amp;quot;id&amp;quot;: &amp;quot;facba1dd-c705-4d5e-b17c-ba590cce422d&amp;quot;&amp;#10;          }&amp;#10;        ]&amp;#10;      }&amp;#10;    ]&amp;#10;  ]&amp;#10;}&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2025-03-30T21:05:48.899318&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.10.0, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

# Create a bar plot showing the average body mass of penguins by species
plt.figure(figsize=(10, 6))
b_plot = sns.barplot(
    x="species", y="body_mass_g", data=penguins, errorbar="sd", palette="Blues_d"
)
plt.title("Average Body Mass of Penguins by Species")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")

# plt.show()
maidr.show(b_plot)
# Out:
# <iframe id="iframe_484f28a2-67f0-45c3-a313-6cb63931a4a9" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; id=&quot;d673de45-843c-4b49-bc87-951be7128aef&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;3dca6d49-b69a-4289-864a-4d2a8757899c&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;5efac32a-3608-4fc7-b3a2-0f0d5b390c54&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;bar&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Average Body Mass of Penguins by Species&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Species&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Body Mass (g)&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Adelie&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 3700.662251655629&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Chinstrap&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 3733.0882352941176&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Gentoo&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 5076.016260162602&amp;#10;              }&amp;#10;            ],&amp;#10;            &amp;quot;selectors&amp;quot;: &amp;quot;path[maidr=&apos;0c0c6176-84c5-4a6e-ac69-d6924b21fabe&apos;]&amp;quot;,&amp;#10;            &amp;quot;id&amp;quot;: &amp;quot;d673de45-843c-4b49-bc87-951be7128aef&amp;quot;&amp;#10;          }&amp;#10;        ]&amp;#10;      }&amp;#10;    ]&amp;#10;  ]&amp;#10;}&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2025-03-30T21:05:59.474313&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.10.0, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#1 ...
