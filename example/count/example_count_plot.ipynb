# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: <object object at 0x105d7f5a0>

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns

# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Create a countplot
count_plot = sns.countplot(x="class", data=titanic)

# Set the title and show the plot
plt.title("Passenger Class Distribution on the Titanic")

# plt.show()
maidr.show(count_plot)
# Out:
# <iframe id="iframe_04801276-1aa3-4a62-b1f4-22a392a35d8c" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;52f2f308-a47d-4d5d-9c21-922f1acafd25&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;2f325ded-006d-4d1d-9eb7-f953def259b9&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;7413777d-e480-45c0-90a6-412e9befd833&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;bar&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Passenger Class Distribution on the Titanic&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;class&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;count&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;First&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 216.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Second&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 184.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: &amp;quot;Third&amp;quot;,&amp;#10;                &amp;quot;y&amp;quot;: 491.0&amp;#10;              }&amp;#10;            ],&amp;#10;            &amp;quot;selectors&amp;quot;: &amp;quot;path[maidr=&apos;2ea607e6-e7a0-4376-859c-5b941e49b523&apos;]&amp;quot;,&amp;#10;            &amp;quot;id&amp;quot;: &amp;quot;52f2f308-a47d-4d5d-9c21-922f1acafd25&amp;quot;&amp;#10;          }&amp;#10;        ]&amp;#10;      }&amp;#10;    ]&amp;#10;  ]&amp;#10;}&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2025-04-09T23:01:42.683139&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.10.0, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8  ...
