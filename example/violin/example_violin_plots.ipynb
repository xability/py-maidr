# %%
import matplotlib.pyplot as plt
import seaborn as sns

import maidr

# Load dataset
diamonds = sns.load_dataset("diamonds")

# Prepare data grouped by cut (5 categories)
groups = []
values = []
for cut, gdf in diamonds.groupby("cut", observed=False):
    groups.append(cut)
    values.append(gdf["price"].dropna().values)

fig, ax = plt.subplots(figsize=(10, 6))

# Matplotlib violin plot: KDE + min/max by default; we also request mean & median
violins = ax.violinplot(
    values,
    showmeans=True,
    showmedians=True,
    showextrema=True,
)

# Set x-ticks to match group labels
ax.set_xticks(range(1, len(groups) + 1))
ax.set_xticklabels(groups)

ax.set_title("Diamond Price Distribution by Cut Quality (Matplotlib Violin)")
ax.set_xlabel("Cut Quality")
ax.set_ylabel("Price (USD)")

# Add number formatter for better screen reader output
ax.yaxis.set_major_formatter("{x:,.0f}")

maidr.show(ax)
# Out:
# /Users/niranjank/Library/Caches/pypoetry/virtualenvs/maidr-_hmc6soT-py3.12/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:479: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# <iframe id="iframe_8b9bbc57-051d-4c54-bb1c-9b952265b4a5" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            (function() {&#10;                var existing = document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr.js&quot;]&apos;);&#10;                if (!existing) {&#10;                    var s = document.createElement(&apos;script&apos;);&#10;                    s.src = &apos;http://localhost:8888/tree/maidr.js&apos;;&#10;                    s.onload = function() { if (window.main) window.main(); };&#10;                    document.head.appendChild(s);&#10;                } else {&#10;                    if (document.readyState === &apos;loading&apos;) {&#10;                        document.addEventListener(&apos;DOMContentLoaded&apos;, function() { if (window.main) window.main(); });&#10;                    } else {&#10;                        if (window.main) window.main();&#10;                    }&#10;                }&#10;            })();&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; id=&quot;fb7af94d-5846-4431-a4be-3c178e2dbdef&quot; maidr=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;fb7af94d-5846-4431-a4be-3c178e2dbdef&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;dadd4d2d-7031-461d-90cd-01dcf226ba76&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;id&amp;quot;: &amp;quot;9336ee53-5499-4789-a1f5-c74853f8dc0c&amp;quot;,&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;violin_box&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Diamond Price Distribution by Cut Quality (Matplotlib Violin)&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Cut Quality&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Price (USD)&amp;quot;,&amp;#10;              &amp;quot;format&amp;quot;: {&amp;#10;                &amp;quot;x&amp;quot;: {&amp;#10;                  &amp;quot;function&amp;quot;: &amp;quot;return String(value)&amp;quot;&amp;#10;                },&amp;#10;                &amp;quot;y&amp;quot;: {&amp;#10;                  &amp;quot;type&amp;quot;: &amp;quot;number&amp;quot;,&amp;#10;                  &amp;quot;decimals&amp;quot;: 0&amp;#10;                }&amp;#10;              }&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Ideal&amp;quot;,&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [],&amp;#10;                &amp;quot;min&amp;quot;: 326.0,&amp;#10;                &amp;quot;q1&amp;quot;: 878.0,&amp;#10;                &amp;quot;q2&amp;quot;: 1810.0,&amp;#10;                &amp;quot;q3&amp;quot;: 4678.5,&amp;#10;                &amp;quot;max&amp;quot;: 18806.0,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;mean&amp;quot;: 3457.542&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Premium&amp;quot;,&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [],&amp;#10;                &amp;quot;min&amp;quot;: 326.0,&amp;#10;                &amp;quot;q1&amp;quot;: 1046.0,&amp;#10;                &amp;quot;q2&amp;quot;: 3185.0,&amp;#10;                &amp;quot;q3&amp;quot;: 6296.0,&amp;#10;                &amp;quot;max&amp;quot;: 18823.0,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;mean&amp;quot;: ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import maidr

# Load dataset
diamonds = sns.load_dataset("diamonds")

# Create violin plot comparing price across cut quality
v = sns.violinplot(
    x="cut",
    y="price",
    data=diamonds,
    inner="box",
    palette="Set2",
)

# Customize the plot
plt.title("Diamond Price Distribution by Cut Quality")
plt.xlabel("Cut Quality")
plt.ylabel("Price (USD)")

# Add number formatter for better screen reader output
plt.gca().yaxis.set_major_formatter("{x:,.0f}")

maidr.show(v)
# Out:
# /Users/niranjank/py-maidr/maidr/patch/violinplot.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = wrapped(*args, **kwargs)
# /Users/niranjank/Library/Caches/pypoetry/virtualenvs/maidr-_hmc6soT-py3.12/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:479: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# <iframe id="iframe_06144fb4-f90f-42c8-9192-90ba397d3560" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            (function() {&#10;                var existing = document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr.js&quot;]&apos;);&#10;                if (!existing) {&#10;                    var s = document.createElement(&apos;script&apos;);&#10;                    s.src = &apos;http://localhost:8888/tree/maidr.js&apos;;&#10;                    s.onload = function() { if (window.main) window.main(); };&#10;                    document.head.appendChild(s);&#10;                } else {&#10;                    if (document.readyState === &apos;loading&apos;) {&#10;                        document.addEventListener(&apos;DOMContentLoaded&apos;, function() { if (window.main) window.main(); });&#10;                    } else {&#10;                        if (window.main) window.main();&#10;                    }&#10;                }&#10;            })();&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&qu