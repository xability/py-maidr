# %%
"""
Multiple KDE overlays with Matplotlib/Scipy and MAIDR
-----------------------------------------------------
This example demonstrates how to plot multiple kernel density estimates (KDEs) for different groups using
raw Matplotlib and Scipy, with MAIDR integration for interactive accessibility and exploration.
"""
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import maidr  # MAIDR integration

# Generate sample data for three groups
np.random.seed(0)
data1 = np.random.normal(loc=0, scale=1, size=200)
data2 = np.random.normal(loc=2, scale=0.5, size=200)
data3 = np.random.normal(loc=-2, scale=1.5, size=200)

plt.figure(figsize=(8, 5))

# Define x ranges for each group
x1 = np.linspace(data1.min() - 1, data1.max() + 1, 200)
x2 = np.linspace(data2.min() - 1, data2.max() + 1, 200)
x3 = np.linspace(data3.min() - 1, data3.max() + 1, 200)

# Compute KDEs
kde1 = gaussian_kde(data1)
kde2 = gaussian_kde(data2)
kde3 = gaussian_kde(data3)

# Plot KDEs with explicit, accessible labels
plt.plot(x1, kde1(x1), label='Group 1 KDE', color='blue', linewidth=2)
plt.plot(x2, kde2(x2), label='Group 2 KDE', color='green', linewidth=2)
plt.plot(x3, kde3(x3), label='Group 3 KDE', color='red', linewidth=2)

plt.title('Multiple KDE Plots with Matplotlib/Scipy')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend(title='Group')
plt.tight_layout()

# Show with MAIDR for interactive accessibility
maidr.show(plt.gcf())
# Out:
# <iframe id="iframe_ee340a00-4bfc-4f32-a071-49d6f2e31a0f" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr/core/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;http://localhost:8888/tree/maidr/core/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;576pt&quot; height=&quot;360pt&quot; viewBox=&quot;0 0 576 360&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;3fb1bc05-fb6c-4994-954e-f7e588187a42&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;bf9040cd-9efb-4da8-b494-4f7bc64b4f77&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;smooth&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Multiple KDE Plots with Matplotlib/Scipy&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Value&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Density&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              [&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.5529898158340787,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00011144425577974627,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 232.43542787865036,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 304.7706092398072&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.5181348681421287,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00014697872468102244,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 233.83435228181412,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 304.75949865672413&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.4832799204501788,&amp;#10;                  &amp;quot;y&amp;quot;: 0.0001920751567839353,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 235.23327668497785,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 304.7453983290388&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.4484249727582292,&amp;#10;                  &amp;quot;y&amp;quot;: 0.0002487306189904283,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 236.63220108814158,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 304.72768383268016&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.4135700250662793,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00031919223999482343,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 238.0311254913053,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 304.7056525566109&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.3787150773743293,&amp;#10;                  &amp;quot;y&amp;quot;: 0.0004059444974145005,&amp;#10;                  &amp;quot;svg_x&amp;q ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import maidr  # MAIDR integration

# Generate sample data for multiple groups
np.random.seed(0)
data1 = np.random.normal(loc=0, scale=1, size=200)
data2 = np.random.normal(loc=2, scale=0.5, size=200)
data3 = np.random.normal(loc=-2, scale=1.5, size=200)

plt.figure(figsize=(8, 5))

# Plot multiple KDEs with seaborn
sns.kdeplot(data1, label='Group 1', color='blue', linewidth=2)
sns.kdeplot(data2, label='Group 2', color='green', linewidth=2)
sns.kdeplot(data3, label='Group 3', color='red', linewidth=2)

plt.title('Multiple KDE Plots with Seaborn')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.tight_layout()

# Show with MAIDR for interactive accessibility
maidr.show(plt.gcf())
# Out:
# <iframe id="iframe_bd2f0a0a-7aad-44aa-92e4-50f6c289554d" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr/core/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;http://localhost:8888/tree/maidr/core/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;576pt&quot; height=&quot;360pt&quot; viewBox=&quot;0 0 576 360&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;4ba3f10e-54be-4575-a7eb-a8b7b9ca8ee0&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;214b5ec0-11cb-4d2e-8926-9c3e69f5e5de&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;smooth&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Multiple KDE Plots with Seaborn&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Value&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Density&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              [&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.6176456780873107,&amp;#10;                  &amp;quot;y&amp;quot;: 6.508623700324297e-05,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 252.60980468792025,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 318.0186812096667&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.5821409227345242,&amp;#10;                  &amp;quot;y&amp;quot;: 8.779302944379987e-05,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 254.02061412107787,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 318.0112436718788&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.546636167381738,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00011729126920219535,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 255.43142355423547,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 318.00158161707947&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.5111314120289516,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00015521187000681216,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 256.8422329873931,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 317.98916084465367&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.475626656676165,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00020345043185560215,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 258.2530424205508,&amp;#10;                  &amp;quot;svg_y&amp;quot;: 317.9733604568392&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: -3.440121901323379,&amp;#10;                  &amp;quot;y&amp;quot;: 0.00026417386175684793,&amp;#10;                  &amp;quot;svg_x&amp;quot;: 259.66 ...

# %%
"""
Multiple KDE overlays with Seaborn and MAIDR
--------------------------------------------
This example demonstrates how to plot multiple kernel density estimates (KDEs) for different groups using Seaborn,
with MAIDR integration for interactive accessibility and exploration.
"""
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import maidr  # MAIDR integration

# Generate sample data for three groups
np.random.seed(0)
data1 = np.random.normal(loc=0, scale=1, size=200)
data2 = np.random.normal(loc=2, scale=0.5, size=200)
data3 = np.random.normal(loc=-2, scale=1.5, size=200)

plt.figure(figsize=(8, 5))

# Plot multiple KDEs with explicit, accessible labels
sns.kdeplot(data1, label='Group 1 KDE', color='blue', linewidth=2)
sns.kdeplot(data2, label='Group 2 KDE', color='green', linewidth=2)
sns.kdeplot(data3, label='Group 3 KDE', color='red', linewidth=2)

plt.title('Multiple KDE Plots with Seaborn')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend(title='Group')
plt.tight_layout()

# Show with MAIDR for interactive accessibility
maidr.show(plt.gcf())
# Out:
# <iframe id="iframe_7617cb48-8332-4f3c-adc7-c07524a2b5c0" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr/core/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;http://localhost:8888/tree/maidr/core/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&qu