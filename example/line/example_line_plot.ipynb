# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: <object object at 0x105a7f5a0>

# %%
import maidr
import matplotlib.pyplot as plt
import seaborn as sns

maidr.set_engine("ts")

# Load the flights dataset from seaborn
flights = sns.load_dataset("flights")

# Pivot the dataset to wide form to make it easier to plot
flights_wide = flights.pivot(index="year", columns="month", values="passengers")

# Create a time series by taking the sum of passengers per year
flights_wide["Total"] = flights_wide.sum(axis=1)

# Reset index to use 'year' as a column
flights_wide.reset_index(inplace=True)

# Plot the total number of passengers per year
plt.figure(figsize=(14, 7))
line_plot = plt.plot(flights_wide["year"], flights_wide["Total"], marker="o")

# Adding title and labels
plt.title("Total Passengers per Year\nFrom the Flights Dataset", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Passengers (Thousands)", fontsize=12)

# Show the plot
# plt.show()
maidr.show(line_plot)
# Out:
# <iframe id="iframe_94957f7e-bba0-4d16-9435-d06060beb3fd" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;1008pt&quot; height=&quot;504pt&quot; viewBox=&quot;0 0 1008 504&quot; version=&quot;1.1&quot; id=&quot;92f583c5-2e27-49f1-8333-47e096279dea&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;790426dd-fa24-4018-9ae7-df90c67e4398&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;2f9a6461-277a-4121-b46d-de129c9a5ef4&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;line&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Total Passengers per Year\nFrom the Flights Dataset&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Year&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Total Passengers (Thousands)&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              [&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1949.0,&amp;#10;                  &amp;quot;y&amp;quot;: 1520.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1950.0,&amp;#10;                  &amp;quot;y&amp;quot;: 1676.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1951.0,&amp;#10;                  &amp;quot;y&amp;quot;: 2042.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1952.0,&amp;#10;                  &amp;quot;y&amp;quot;: 2364.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1953.0,&amp;#10;                  &amp;quot;y&amp;quot;: 2700.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1954.0,&amp;#10;                  &amp;quot;y&amp;quot;: 2867.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1955.0,&amp;#10;                  &amp;quot;y&amp;quot;: 3408.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 1956.0,&amp;# ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns

maidr.set_engine("ts")

# Load the 'tips' dataset from seaborn
tips = sns.load_dataset("tips")

# Choose a specific subset of the dataset (e.g., data for 'Thursday')
subset_data = tips[tips["day"] == "Thur"]

# Create a line plot
plt.figure(figsize=(10, 6))
line_plot = sns.lineplot(
    data=subset_data,
    x="total_bill",
    y="tip",
    markers=True,
    style="day",
    legend=False,
)
plt.title("Line Plot of Tips vs Total Bill (Thursday)")
plt.xlabel("Total Bill")
plt.ylabel("Tip")

# plt.show()
maidr.show(line_plot)
# Out:
# <iframe id="iframe_69e178e4-9daa-4c01-affc-34eb661dccc4" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; id=&quot;80d75608-a0d3-4b3c-a5f7-0bee7f6e10b1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;392cd6b1-5960-4834-ba48-371c0cdddfa0&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;c122f2ae-e3ec-44a3-8fff-789c7ac00d82&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;line&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Line Plot of Tips vs Total Bill (Thursday)&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Total Bill&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Tip&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              [&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 7.51,&amp;#10;                  &amp;quot;y&amp;quot;: 2.0,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 7.56,&amp;#10;                  &amp;quot;y&amp;quot;: 1.44,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 8.35,&amp;#10;                  &amp;quot;y&amp;quot;: 1.5,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 8.51,&amp;#10;                  &amp;quot;y&amp;quot;: 1.25,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 8.52,&amp;#10;                  &amp;quot;y&amp;quot;: 1.48,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 9.78,&amp;#10;                  &amp;quot;y&amp;quot;: 1.73,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 10.07,&amp;#10;                  &amp;quot;y&amp;quot;: 1.83,&amp;#10;                  &amp;quot;fill&amp;quot;: &amp;quot;_child0&amp;quot;&amp;#10;                },&amp;#10;                {&amp;#10;                  &amp;quot;x&amp;quot;: 10.33,&amp;#10;                  &amp;quot;y&amp;quot;: 2.0,&amp;#10;    ...
