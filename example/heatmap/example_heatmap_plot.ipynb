# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: <object object at 0x10797f5a0>

# %%
import maidr
import matplotlib.pyplot as plt
import numpy as np


vegetables = [
    "cucumber",
    "tomato",
    "lettuce",
    "asparagus",
    "potato",
    "wheat",
    "barley",
]
farmers = [
    "Farmer Joe",
    "Upland Bros.",
    "Smith Gardening",
    "Agrifun",
    "Organiculture",
    "BioGoods Ltd.",
    "Cornylee Corp.",
]

harvest = np.array(
    [
        [0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
        [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
        [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
        [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
        [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
        [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
        [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3],
    ]
)

fig, ax = plt.subplots()
im = ax.imshow(harvest, fill_label="Harvest")
im.get_array()

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        ax.text(j, i, harvest[i, j], ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()

# plt.show()
maidr.show(im)
# Out:
# <iframe id="iframe_2d144279-60be-4444-836b-0f416a3dd32d" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;f8a904b5-373e-495a-8280-10a9ebf164cd&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;0aee6dab-0b6e-41bd-9995-30b5c2247159&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;heat&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Harvest of local farmers (in tons/year)&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;&amp;quot;,&amp;#10;              &amp;quot;fill&amp;quot;: &amp;quot;Harvest&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: {&amp;#10;              &amp;quot;points&amp;quot;: [&amp;#10;                [&amp;#10;                  0.8,&amp;#10;                  2.4,&amp;#10;                  2.5,&amp;#10;                  3.9,&amp;#10;                  0.0,&amp;#10;                  4.0,&amp;#10;                  0.0&amp;#10;                ],&amp;#10;                [&amp;#10;                  2.4,&amp;#10;                  0.0,&amp;#10;                  4.0,&amp;#10;                  1.0,&amp;#10;                  2.7,&amp;#10;                  0.0,&amp;#10;                  0.0&amp;#10;                ],&amp;#10;                [&amp;#10;                  1.1,&amp;#10;                  2.4,&amp;#10;                  0.8,&amp;#10;                  4.3,&amp;#10;                  1.9,&amp;#10;                  4.4,&amp;#10;                  0.0&amp;#10;                ],&amp;#10;                [&amp;#10;                  0.6,&amp;#10;                  0.0,&amp;#10;                  0.3,&amp;#10;                  0.0,&amp;#10;                  3.1,&amp;#10;                  0.0,&amp;#10;                  0.0&amp;#10;                ],&amp;#10;                [&amp;#10;                  0.7,&amp;#10;                  1.7,&amp;#10;                  0.6,&amp;#10;                  2.6,&amp;#10;                  2.2,&amp;#10;                  6.2,&amp;#10;                  0.0&amp;#10;                ],&amp;#10;                [&amp;#10;                  1.3,&amp;#10;                  1.2,&amp;#10;                  0.0,&amp;#10;                  0.0,&amp;#10;                  0.0,&amp;#10;                  3.2,&amp;#10;                  5.1&amp;#10;                ],&amp;#10;                [&amp;#10;                  0.1,&amp;#10;                  2.0,&amp;#10;                  0.0,&amp;#10;                  1.4,&amp;#10;                  0.0,&amp;#10 ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load an example dataset from seaborn
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")

# Plot a heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(glue, annot=True, fill_label="Score")
plt.title("Heatmap of Model Scores by Task")

# Show the plot
# plt.show()
maidr.show(heatmap)
# Out:
# <iframe id="iframe_5ecbf207-8c5c-420a-9812-55af294ce823" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;576pt&quot; viewBox=&quot;0 0 720 576&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;1d36764e-0b2e-497c-bdbd-110912731d07&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;a665c24e-f96d-4058-8867-1f27e38eac4a&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;heat&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Heatmap of Model Scores by Task&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Task&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Model&amp;quot;,&amp;#10;              &amp;quot;fill&amp;quot;: &amp;quot;Score&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: {&amp;#10;              &amp;quot;points&amp;quot;: [&amp;#10;                [&amp;#10;                  60.5,&amp;#10;                  86.7,&amp;#10;                  89.3,&amp;#10;                  92.7,&amp;#10;                  72.1,&amp;#10;                  70.1,&amp;#10;                  94.9,&amp;#10;                  87.6&amp;#10;                ],&amp;#10;                [&amp;#10;                  11.6,&amp;#10;                  65.6,&amp;#10;                  81.8,&amp;#10;                  74.6,&amp;#10;                  62.5,&amp;#10;                  57.4,&amp;#10;                  82.8,&amp;#10;                  70.3&amp;#10;                ],&amp;#10;                [&amp;#10;                  18.6,&amp;#10;                  67.6,&amp;#10;                  83.9,&amp;#10;                  74.3,&amp;#10;                  60.1,&amp;#10;                  58.4,&amp;#10;                  83.0,&amp;#10;                  72.8&amp;#10;                ],&amp;#10;                [&amp;#10;                  18.5,&amp;#10;                  65.4,&amp;#10;                  78.7,&amp;#10;                  70.8,&amp;#10;                  60.6,&amp;#10;                  52.7,&amp;#10;                  81.9,&amp;#10;                  64.4&amp;#10;                ],&amp;#10;                [&amp;#10;                  32.1,&amp;#10;                  67.2,&amp;#10;                  84.7,&amp;#10;                  75.5,&amp;#10;                  61.1,&amp;#10;                  57.4,&amp;#10;                  89.3,&amp;#10;                  70.3&amp;#10;                ],&amp;#10;                [&amp;#10;                  75.5,&amp;#10;                  92.3,&amp;#10;                  93.9,&amp;#10;                  97.3,&amp;#10;                  75.2,&amp;#10;                  92.6,&amp;#10;                  97.8,&amp;#10;              ...
