# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
import matplotlib.pyplot as plt
import maidr
import numpy as np

# Generating random data for three different groups
data_group1 = np.random.normal(100, 10, 200)
data_group2 = np.random.normal(90, 20, 200)
data_group3 = np.random.normal(80, 30, 200)

# Combine these different datasets into a list
data_to_plot = [data_group1, data_group2, data_group3]


# Create the boxplot
def boxplot(is_vert: bool):
    plt.figure()
    bp = plt.boxplot(data_to_plot, patch_artist=True, vert=is_vert)

    colors = ["lightblue", "lightgreen", "tan"]
    for patch, color in zip(bp["boxes"], colors):
        patch.set_facecolor(color)

    if is_vert:
        plt.xticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Vertical Box Plot Example")
        plt.xlabel("Group")
        plt.ylabel("Values")
    else:
        plt.yticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Horizontal Box Plot Example")
        plt.ylabel("Group")
        plt.xlabel("Values")

    return bp


# Create the vertical boxplot
vert = boxplot(is_vert=True)
# plt.show()
maidr.show(vert)
# Out:
# <iframe id="iframe_f14f4152-98c4-4ecb-ad47-3b4fa3c904a2" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;38f289cf-244f-4bc8-97b5-b3a6dea403c9&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;b9975739-cbd6-4241-bcee-3ce807056b3a&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;box&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Vertical Box Plot Example&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Group&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Values&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  74.14017197812599&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 76.07607615956718,&amp;#10;                &amp;quot;q1&amp;quot;: 93.31275635571961,&amp;#10;                &amp;quot;q2&amp;quot;: 99.72536157428677,&amp;#10;                &amp;quot;q3&amp;quot;: 105.28847897849502,&amp;#10;                &amp;quot;max&amp;quot;: 122.72401664151165,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [&amp;#10;                  124.21671740948096,&amp;#10;                  124.67697608205249&amp;#10;                ],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Group 1&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  20.552329954870878&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 46.03865588203669,&amp;#10;                &amp;quot;q1&amp;quot;: 77.06836990198404,&amp;#10;                &amp;quot;q2&amp;quot;: 90.67276006439778,&amp;#10;                &amp;quot;q3&amp;quot;: 102.75748819654471,&amp;#10;                &amp;quot;max&amp;quot;: 137.10920385031355,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Group 2&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  -5.022501788814595,&amp;#10;                  -3.053706849520248&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 5.631326037969693,&amp;#10;                &amp;quot;q1&amp;quot;: 60.674992180784685,&amp;#10;                &amp;quot;q2&amp;quot;: 80.77267043408744,&amp;#10;                &amp;quot;q3&amp;quot;: 101.92573724284739,&amp;#10;               ...

# %%
# Create the vertical boxplot
horz = boxplot(is_vert=False)
# plt.show()
maidr.show(horz)
# Out:
# <iframe id="iframe_80c0222b-bd8c-4b16-aa45-dd8fbafd4444" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;f7299c49-8e9b-4128-b825-d3b420d684f6&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;f0df95b0-475e-4f4a-8fc5-ddff45738fe4&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;box&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Horizontal Box Plot Example&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Values&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Group&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  -12.538725717961686,&amp;#10;                  -1.9569925839581126,&amp;#10;                  -0.5161011794671566&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 3.5433029758609935,&amp;#10;                &amp;quot;q1&amp;quot;: 59.030747560136206,&amp;#10;                &amp;quot;q2&amp;quot;: 80.88091171981907,&amp;#10;                &amp;quot;q3&amp;quot;: 96.07378114352328,&amp;#10;                &amp;quot;max&amp;quot;: 143.0917647237164,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Group 3&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [],&amp;#10;                &amp;quot;min&amp;quot;: 39.76513576206614,&amp;#10;                &amp;quot;q1&amp;quot;: 73.16574341183262,&amp;#10;                &amp;quot;q2&amp;quot;: 87.97620307887544,&amp;#10;                &amp;quot;q3&amp;quot;: 100.0267486736628,&amp;#10;                &amp;quot;max&amp;quot;: 138.6172064666885,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;Group 2&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  62.89945944646505,&amp;#10;                  69.72162404882735&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 72.91521983417195,&amp;#10;                &amp;quot;q1&amp;quot;: 92.49744232535173,&amp;#10;                &amp;quot;q2&amp;quot;: 100.52814308300758,&amp;#10;                &amp;quot;q3&amp;quot;: 105.77731132677283,&amp;#10;                &amp;quot;max&amp;quot;: 124.13559579791895,&amp;#10;                &amp;quot;upperOutlie ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")


def boxplot(orientation: str, fig_num: int):
    # Start a new figure
    plt.figure(num=fig_num)

    # Create box plot
    if orientation == "v":
        box_plot = sns.boxplot(
            x="species", y="petal_length", data=iris, orient=orientation
        )
        plt.xlabel("Species")
        plt.ylabel("Petal Length (cm)")
    else:
        box_plot = sns.boxplot(
            x="petal_length", y="species", data=iris, orient=orientation
        )
        plt.ylabel("Species")
        plt.xlabel("Petal Length (cm)")

    # Adding labels and title
    plt.title("Box Plot of Petal Length by Iris Species")

    return box_plot


# Create the vertical boxplot
vert = boxplot(orientation="v", fig_num=1)
# plt.show()
maidr.show(vert)
# Out:
# <iframe id="iframe_5856a6c9-e157-44ec-a083-1ffda585ed4b" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;9b0e04a4-8cea-4c77-92c2-72442d978405&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;4256889c-f876-49da-a500-dd2c62812f03&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;box&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Box Plot of Petal Length by Iris Species&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Species&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Petal Length (cm)&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  1.0,&amp;#10;                  1.1&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 1.2,&amp;#10;                &amp;quot;q1&amp;quot;: 1.4,&amp;#10;                &amp;quot;q2&amp;quot;: 1.5,&amp;#10;                &amp;quot;q3&amp;quot;: 1.5750000000000002,&amp;#10;                &amp;quot;max&amp;quot;: 1.7,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [&amp;#10;                  1.9,&amp;#10;                  1.9&amp;#10;                ],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;setosa&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  3.0&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 3.3,&amp;#10;                &amp;quot;q1&amp;quot;: 4.0,&amp;#10;                &amp;quot;q2&amp;quot;: 4.35,&amp;#10;                &amp;quot;q3&amp;quot;: 4.6,&amp;#10;                &amp;quot;max&amp;quot;: 5.1,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;versicolor&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [],&amp;#10;                &amp;quot;min&amp;quot;: 4.5,&amp;#10;                &amp;quot;q1&amp;quot;: 5.1,&amp;#10;                &amp;quot;q2&amp;quot;: 5.55,&amp;#10;                &amp;quot;q3&amp;quot;: 5.875,&amp;#10;                &amp;quot;max&amp;quot;: 6.9,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;virginica&amp;quot;&amp;#10;              }&amp;#10;            ],&amp;#10;            &amp;quot;orientation&amp;quot;: &amp;quot;vert&amp;quo ...

# %%
# Create the vertical boxplot
horz = boxplot(orientation="h", fig_num=2)
# plt.show()
maidr.show(horz)
# Out:
# <iframe id="iframe_3636acf4-2ca1-418e-aaa1-5800364c4ecc" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;c1be4f45-3f52-4e2d-916e-b200a8702880&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;4ad2ec4f-e21d-42a6-ae61-0d9a08f3b213&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;box&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Box Plot of Petal Length by Iris Species&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Petal Length (cm)&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Species&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [],&amp;#10;                &amp;quot;min&amp;quot;: 4.5,&amp;#10;                &amp;quot;q1&amp;quot;: 5.1,&amp;#10;                &amp;quot;q2&amp;quot;: 5.55,&amp;#10;                &amp;quot;q3&amp;quot;: 5.875,&amp;#10;                &amp;quot;max&amp;quot;: 6.9,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;virginica&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  3.0&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 3.3,&amp;#10;                &amp;quot;q1&amp;quot;: 4.0,&amp;#10;                &amp;quot;q2&amp;quot;: 4.35,&amp;#10;                &amp;quot;q3&amp;quot;: 4.6,&amp;#10;                &amp;quot;max&amp;quot;: 5.1,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;versicolor&amp;quot;&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;lowerOutliers&amp;quot;: [&amp;#10;                  1.0,&amp;#10;                  1.1&amp;#10;                ],&amp;#10;                &amp;quot;min&amp;quot;: 1.2,&amp;#10;                &amp;quot;q1&amp;quot;: 1.4,&amp;#10;                &amp;quot;q2&amp;quot;: 1.5,&amp;#10;                &amp;quot;q3&amp;quot;: 1.5750000000000002,&amp;#10;                &amp;quot;max&amp;quot;: 1.7,&amp;#10;                &amp;quot;upperOutliers&amp;quot;: [&amp;#10;                  1.9,&amp;#10;                  1.9&amp;#10;                ],&amp;#10;                &amp;quot;fill&amp;quot;: &amp;quot;setosa&amp;quot;&amp;#10;              }&amp;#10;            ],&amp;#10;            &amp;quot;orientation&amp;quot;: &amp;quot;horz&amp;quo ...
