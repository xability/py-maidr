# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: <object object at 0x10697f5a0>

# %%
import maidr
import matplotlib.pyplot as plt
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")

# Plot sepal_length vs sepal_width
plt.figure(figsize=(10, 6))  # Optional: Sets the figure size
scatter_plot = plt.scatter(
    iris["sepal_length"], iris["sepal_width"], c="blue", label="Iris Data Points"
)
plt.title("Iris Dataset: Sepal Length vs Sepal Width")  # Title of the plot
plt.xlabel("Sepal Length (cm)")  # X-axis label
plt.ylabel("Sepal Width (cm)")  # Y-axis label
plt.legend()  # Shows the legend

# plt.show()
maidr.show(scatter_plot)
# Out:
# <iframe id="iframe_7a9beb32-75fa-4c9a-b97f-51f3fa5c2f1f" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;53577825-a46d-49f4-95d3-c7a2c09d9300&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;4c9c53bf-fc05-448f-8169-1ed96ad2d9fd&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;point&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Iris Dataset: Sepal Length vs Sepal Width&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Sepal Length (cm)&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Sepal Width (cm)&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.1,&amp;#10;                &amp;quot;y&amp;quot;: 3.5&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.9,&amp;#10;                &amp;quot;y&amp;quot;: 3.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.7,&amp;#10;                &amp;quot;y&amp;quot;: 3.2&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.6,&amp;#10;                &amp;quot;y&amp;quot;: 3.1&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.0,&amp;#10;                &amp;quot;y&amp;quot;: 3.6&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.4,&amp;#10;                &amp;quot;y&amp;quot;: 3.9&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.6,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.0,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.4,&amp;#10;                &amp;quot;y&amp;quot;: 2.9&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.9,&amp;#10;                &amp;quot;y&amp;quot;: 3.1&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.4,&amp;#10;                &amp;quot;y&amp;quot;: 3.7&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.8,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.8,&amp ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")

# Create a scatter plot
scatter_plot = sns.scatterplot(
    data=iris, x="sepal_length", y="sepal_width", hue="species"
)

# Adding title and labels (optional)
plt.title("Iris Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")

# Show the plot
# plt.show()
maidr.show(scatter_plot)
# Out:
# <iframe id="iframe_8a752a00-76c3-4cab-b36c-3932e982b623" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;8fe72d2c-6671-4f08-a082-148cb7eaf663&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;d42cddcb-0346-406c-8ae1-2d68f9a57272&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;point&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Iris Sepal Length vs Sepal Width&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Sepal Length&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Sepal Width&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.1,&amp;#10;                &amp;quot;y&amp;quot;: 3.5&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.9,&amp;#10;                &amp;quot;y&amp;quot;: 3.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.7,&amp;#10;                &amp;quot;y&amp;quot;: 3.2&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.6,&amp;#10;                &amp;quot;y&amp;quot;: 3.1&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.0,&amp;#10;                &amp;quot;y&amp;quot;: 3.6&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.4,&amp;#10;                &amp;quot;y&amp;quot;: 3.9&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.6,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.0,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.4,&amp;#10;                &amp;quot;y&amp;quot;: 2.9&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.9,&amp;#10;                &amp;quot;y&amp;quot;: 3.1&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 5.4,&amp;#10;                &amp;quot;y&amp;quot;: 3.7&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.8,&amp;#10;                &amp;quot;y&amp;quot;: 3.4&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 4.8,&amp;#10;       ...
