# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.nonparametric.smoothers_lowess import lowess
import maidr

# Generate synthetic data
np.random.seed(0)
x = np.linspace(0, 10, 100)
y = np.sin(x) + 0.3 * np.random.randn(100)

# LOWESS smoothing
smoothed = lowess(y, x, frac=0.3)  # frac controls the amount of smoothing

fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(x, y, color='blue', alpha=0.6, label='Data points')
# Plot the smooth (LOWESS) line
ax.plot(smoothed[:, 0], smoothed[:, 1], color='red', lw=2, label='LOWESS smooth')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Matplotlib: Scatter with LOWESS Smooth Line')
ax.legend()
plt.tight_layout()

# Show with MAIDR (if available)
maidr.show(ax)
# Out:
# <iframe id="iframe_c236bb65-10b3-4756-bc60-0a5b677dec93" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;432pt&quot; height=&quot;288pt&quot; viewBox=&quot;0 0 432 288&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;1cebb57b-cf0f-4c6c-b6fa-8fc87281914b&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;d716fad2-19fd-4c0b-a006-4379e4f9890d&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;point&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Matplotlib: Scatter with LOWESS Smooth Line&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;x&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;y&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.0,&amp;#10;                &amp;quot;y&amp;quot;: 0.5292157037902991&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.10101010101010101,&amp;#10;                &amp;quot;y&amp;quot;: 0.22088558276827158&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.20202020202020202,&amp;#10;                &amp;quot;y&amp;quot;: 0.4942702517544072&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.30303030303030304,&amp;#10;                &amp;quot;y&amp;quot;: 0.9706817642080784&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.40404040404040403,&amp;#10;                &amp;quot;y&amp;quot;: 0.95340400919332&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.5050505050505051,&amp;#10;                &amp;quot;y&amp;quot;: 0.1906682764750114&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.6060606060606061,&amp;#10;                &amp;quot;y&amp;quot;: 0.8546606321666425&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.7070707070707071,&amp;#10;                &amp;quot;y&amp;quot;: 0.6042023510163972&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.8080808080808081,&amp;#10;                &amp;quot;y&amp;quot;: 0.6919969059413931&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.9090909090909091,&amp;#10;                &amp;quot;y&amp;quot;: 0.912125013425769&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 1.0101010101010102,&amp;#10;                &amp;quot;y&amp;quot ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import maidr

np.random.seed(0)
x = np.linspace(0, 10, 100)
y = np.sin(x) + 0.3 * np.random.randn(100)

plt.figure(figsize=(6, 4))
plot = sns.regplot(
    x=x,
    y=y,
    lowess=True,
    scatter_kws={'s': 30, 'alpha': 0.6},
    line_kws={'color': 'red', 'lw': 2}
)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatterplot with LOESS (Seaborn)')
plt.tight_layout()

# Show the plot using maidr instead of plt.show()
maidr.show(plot)
# Out:
# <iframe id="iframe_3bbdedf3-a1e6-404c-8e8f-d54c2e15a97a" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;432pt&quot; height=&quot;288pt&quot; viewBox=&quot;0 0 432 288&quot; version=&quot;1.1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;492a2d0e-5d26-47c0-b78a-8b61f66d2b3f&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;06335553-cec0-451f-864b-260fedba40d4&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;point&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Scatterplot with LOESS (Seaborn)&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;x&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;y&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.0,&amp;#10;                &amp;quot;y&amp;quot;: 0.5292157037902991&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.10101010101010101,&amp;#10;                &amp;quot;y&amp;quot;: 0.22088558276827158&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.20202020202020202,&amp;#10;                &amp;quot;y&amp;quot;: 0.4942702517544072&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.30303030303030304,&amp;#10;                &amp;quot;y&amp;quot;: 0.9706817642080784&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.40404040404040403,&amp;#10;                &amp;quot;y&amp;quot;: 0.95340400919332&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.5050505050505051,&amp;#10;                &amp;quot;y&amp;quot;: 0.1906682764750114&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.6060606060606061,&amp;#10;                &amp;quot;y&amp;quot;: 0.8546606321666425&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.7070707070707071,&amp;#10;                &amp;quot;y&amp;quot;: 0.6042023510163972&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.8080808080808081,&amp;#10;                &amp;quot;y&amp;quot;: 0.6919969059413931&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 0.9090909090909091,&amp;#10;                &amp;quot;y&amp;quot;: 0.912125013425769&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;x&amp;quot;: 1.0101010101010102,&amp;#10;                &amp;quot;y&amp;quot;: 0.890098 ...
