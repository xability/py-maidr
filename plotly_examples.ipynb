# %% [markdown]
# # Plotly Examples for maidr
#
# This notebook demonstrates all supported Plotly plot types with maidr accessibility features.

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns

import maidr

# %% [markdown]
# ## 1. Bar Plot

# %%
penguins = sns.load_dataset("penguins")
avg_mass = penguins.groupby("species")["body_mass_g"].mean()

fig = go.Figure(
    data=[
        go.Bar(
            x=avg_mass.index.tolist(),
            y=avg_mass.values.tolist(),
            marker_color=["#4c72b0", "#55a868", "#c44e52"],
        )
    ],
    layout=go.Layout(
        title="Average Body Mass of Penguins by Species",
        xaxis=dict(title="Species"),
        yaxis=dict(title="Body Mass (g)", tickformat=",.0f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_fc1bb2da-ba1a-4dcc-9be1-6c896feecdca" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;a6cce9b3-5df1-4ec3-b999-3943e57551c8&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;a6cce9b3-5df1-4ec3-b999-3943e57551c8&quot
# ...

# %% [markdown]
# ## 2. Dodged (Grouped) Bar Plot

# %%
fig = go.Figure(
    data=[
        go.Bar(name="Male", x=["Adelie", "Chinstrap", "Gentoo"], y=[4043, 3939, 5485]),
        go.Bar(name="Female", x=["Adelie", "Chinstrap", "Gentoo"], y=[3369, 3527, 4680]),
    ],
    layout=go.Layout(
        title="Average Body Mass by Species and Sex",
        xaxis=dict(title="Species"),
        yaxis=dict(title="Body Mass (g)", tickformat=",.0f"),
        barmode="group",
    ),
)

maidr.show(fig)

# %% [markdown]
# ## 3. Stacked Bar Plot

# %%
fig = go.Figure(
    data=[
        go.Bar(name="Adelie", x=["Torgersen", "Biscoe", "Dream"], y=[47, 44, 56]),
        go.Bar(name="Chinstrap", x=["Torgersen", "Biscoe", "Dream"], y=[0, 0, 68]),
        go.Bar(name="Gentoo", x=["Torgersen", "Biscoe", "Dream"], y=[0, 124, 0]),
    ],
    layout=go.Layout(
        title="Penguin Count by Island (Stacked)",
        xaxis=dict(title="Island"),
        yaxis=dict(title="Count", tickformat=".0f"),
        barmode="stack",
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_3c517bc5-c6f2-42c0-8f9e-3c7ac3d16520" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;8098d782-9799-4d76-896c-f01d7837f5ce&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;8098d782-9799-4d76-896c-f01d7837f5ce&quot
# ...

# %% [markdown]
# ## 4. Count Plot (Categorical Histogram)

# %%
species = [
    "Adelie", "Adelie", "Adelie", "Adelie", "Adelie",
    "Chinstrap", "Chinstrap", "Chinstrap",
    "Gentoo", "Gentoo", "Gentoo", "Gentoo",
]

fig = go.Figure(
    data=[go.Histogram(x=species)],
    layout=go.Layout(
        title="Penguin Species Count",
        xaxis=dict(title="Species"),
        yaxis=dict(title="Count", tickformat=".0f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_6ba64135-64fb-4131-9bde-18b604a03e55" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;13f2c548-90a5-41c0-8665-d385b6e1b1f5&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;13f2c548-90a5-41c0-8665-d385b6e1b1f5&quot
# ...

# %% [markdown]
# ## 5. Histogram

# %%
iris = sns.load_dataset("iris")

fig = go.Figure(
    data=[
        go.Histogram(
            x=iris["petal_length"].tolist(),
            nbinsx=20,
            marker=dict(color="steelblue", line=dict(color="black", width=1)),
        )
    ],
    layout=go.Layout(
        title="Histogram of Petal Lengths in Iris Dataset",
        xaxis=dict(title="Petal Length (cm)", tickformat=".1f"),
        yaxis=dict(title="Frequency", tickformat=".0f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_dc03b1d7-dee8-487d-b67c-a1d3b4f7e098" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;ecda87bf-94ee-4d8f-b18f-8145cfca2374&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;ecda87bf-94ee-4d8f-b18f-8145cfca2374&quot
# ...

# %% [markdown]
# ## 6. Box Plot (Vertical)

# %%
np.random.seed(42)
data_group1 = np.append(np.random.normal(100, 10, 200), [150, 160, 50, 40])
data_group2 = np.append(np.random.normal(90, 20, 200), [180, 190, 10, 20])
data_group3 = np.append(np.random.normal(80, 30, 200), [200, 210, -10, -20])

fig = go.Figure()
fig.add_trace(go.Box(y=data_group1.tolist(), name="Group 1", marker_color="lightblue"))
fig.add_trace(go.Box(y=data_group2.tolist(), name="Group 2", marker_color="lightgreen"))
fig.add_trace(go.Box(y=data_group3.tolist(), name="Group 3", marker_color="tan"))

fig.update_layout(
    title="Vertical Box Plot",
    xaxis=dict(title="Group"),
    yaxis=dict(title="Values", tickformat=".1f"),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_6f6261e3-5838-48f7-8694-cedb8f810fd8" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;d5b6a467-9eab-48b6-a538-47898053107b&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;d5b6a467-9eab-48b6-a538-47898053107b&quot
# ...

# %% [markdown]
# ## 7. Box Plot (Horizontal)

# %%
np.random.seed(42)

fig = go.Figure()
fig.add_trace(go.Box(x=np.random.normal(100, 10, 200).tolist(), name="Group 1", marker_color="lightblue"))
fig.add_trace(go.Box(x=np.random.normal(90, 20, 200).tolist(), name="Group 2", marker_color="lightgreen"))
fig.add_trace(go.Box(x=np.random.normal(80, 30, 200).tolist(), name="Group 3", marker_color="tan"))

fig.update_layout(
    title="Horizontal Box Plot",
    xaxis=dict(title="Values", tickformat=".1f"),
    yaxis=dict(title="Group"),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_8189b4c6-84a4-4872-a276-87a1d41c08b0" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;184b5015-5f43-424a-9f68-353d1c2ae986&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;184b5015-5f43-424a-9f68-353d1c2ae986&quot
# ...

# %% [markdown]
# ## 8. Heatmap

# %%
vegetables = ["cucumber", "tomato", "lettuce", "asparagus", "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening", "Agrifun",
           "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([
    [0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3],
])

fig = go.Figure(
    data=[
        go.Heatmap(
            z=harvest.tolist(),
            x=farmers,
            y=vegetables,
            colorbar=dict(title="Tons/Year", tickformat=".1f"),
        )
    ],
    layout=go.Layout(
        title="Harvest of Local Farmers (in tons/year)",
        xaxis=dict(title="Farmers"),
        yaxis=dict(title="Vegetables"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_9cf4ad50-fd96-437e-8e77-6bf7c50289be" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;b07fa9e1-d82f-47d2-a2d6-fb1e11799d7c&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;b07fa9e1-d82f-47d2-a2d6-fb1e11799d7c&quot
# ...

# %% [markdown]
# ## 9. Line Plot

# %%
flights = sns.load_dataset("flights")
flights_wide = flights.pivot(index="year", columns="month", values="passengers")
flights_wide["Total"] = flights_wide.sum(axis=1)
flights_wide.reset_index(inplace=True)

fig = go.Figure(
    data=[
        go.Scatter(
            x=flights_wide["year"].tolist(),
            y=flights_wide["Total"].tolist(),
            mode="lines",
            name="Total Passengers",
        )
    ],
    layout=go.Layout(
        title="Total Passengers per Year",
        xaxis=dict(title="Year"),
        yaxis=dict(title="Total Passengers (Thousands)", tickformat=",.0f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_afa24e29-88a3-4fcb-a532-feb6ef353bc2" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;b8ee5506-323b-4b14-981c-5e8d2bbf06c5&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;b8ee5506-323b-4b14-981c-5e8d2bbf06c5&quot
# ...

# %% [markdown]
# ## 10. Multi-Line Plot

# %%
fig = go.Figure(
    data=[
        go.Scatter(x=[2019, 2020, 2021, 2022, 2023], y=[100, 120, 115, 140, 160],
                   mode="lines", name="Product A"),
        go.Scatter(x=[2019, 2020, 2021, 2022, 2023], y=[80, 95, 110, 105, 130],
                   mode="lines", name="Product B"),
        go.Scatter(x=[2019, 2020, 2021, 2022, 2023], y=[60, 70, 85, 90, 100],
                   mode="lines", name="Product C"),
    ],
    layout=go.Layout(
        title="Sales Trends by Product",
        xaxis=dict(title="Year"),
        yaxis=dict(title="Sales (units)", tickformat=",.0f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_84d088af-4e1a-4f29-8db6-5d6b3601c477" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;1865d5d8-09eb-4c4d-a3fd-7c0bafd1e07c&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;1865d5d8-09eb-4c4d-a3fd-7c0bafd1e07c&quot
# ...

# %% [markdown]
# ## 11. Scatter Plot

# %%
iris = sns.load_dataset("iris")

fig = go.Figure(
    data=[
        go.Scatter(
            x=iris["sepal_length"].tolist(),
            y=iris["sepal_width"].tolist(),
            mode="markers",
            marker=dict(color="blue", size=6),
            name="Iris Data Points",
        )
    ],
    layout=go.Layout(
        title="Iris Dataset: Sepal Length vs Sepal Width",
        xaxis=dict(title="Sepal Length (cm)", tickformat=".1f"),
        yaxis=dict(title="Sepal Width (cm)", tickformat=".1f"),
    ),
)

maidr.show(fig)
# Out:
# <iframe id="iframe_6b7076f9-9bba-41e2-b127-e74c3d836c6e" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;21947134-a188-4bec-aab4-6172d2f6a35a&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;21947134-a188-4bec-aab4-6172d2f6a35a&quot
# ...

# %% [markdown]
# ## 12. KDE (Histogram + KDE Overlay)

# %%
from scipy.stats import gaussian_kde

np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 300), np.random.normal(4, 1.5, 200)])

kde = gaussian_kde(data)
x_range = np.linspace(data.min() - 1, data.max() + 1, 200)
kde_values = kde(x_range)

fig = go.Figure()
fig.add_trace(go.Histogram(x=data.tolist(), nbinsx=30, histnorm="probability density",
                           name="Histogram", opacity=0.6))
fig.add_trace(go.Scatter(x=x_range.tolist(), y=kde_values.tolist(), mode="lines",
                         name="KDE", line=dict(color="red", width=2)))
fig.update_layout(title="Histogram with KDE Overlay",
                  xaxis=dict(title="Value", tickformat=".1f"),
                  yaxis=dict(title="Density", tickformat=".3f"))

maidr.show(fig)
# Out:
# <iframe id="iframe_060cfc88-5914-402e-b0e9-a73101b3011f" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;83e2c74d-974f-4bf4-b35b-c7b79c820f7a&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;83e2c74d-974f-4bf4-b35b-c7b79c820f7a&quot
# ...

# %% [markdown]
# ## 13. Regression (Scatter + Trend Line)

# %%
np.random.seed(42)
x = np.linspace(0, 10, 50)
y = 2.5 * x + 3 + np.random.normal(0, 2, 50)

coeffs = np.polyfit(x, y, 1)
trend_y = np.polyval(coeffs, x)

fig = go.Figure()
fig.add_trace(go.Scatter(x=x.tolist(), y=y.tolist(), mode="markers",
                         name="Data", marker=dict(color="steelblue")))
fig.add_trace(go.Scatter(x=x.tolist(), y=trend_y.tolist(), mode="lines",
                         name="Regression", line=dict(color="red", width=2)))
fig.update_layout(title="Scatter Plot with Regression Line",
                  xaxis=dict(title="X", tickformat=".1f"),
                  yaxis=dict(title="Y", tickformat=".2f"))

maidr.show(fig)
# Out:
# <iframe id="iframe_e84c98f8-0594-461d-bf96-361b205f431b" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;3511b589-df6b-4432-a392-f2dece4ac077&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:100%; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;3511b589-df6b-4432-a392-f2dece4ac077&quot
# ...

# %% [markdown]
# ## 15. Multipanel Plot (Line + Bar + Scatter)

# %%
x_line = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y_line = np.array([2, 4, 1, 5, 3, 7, 6, 8])

np.random.seed(42)
categories = ["A", "B", "C", "D", "E"]
values = (np.random.rand(5) * 10).tolist()

x_scatter = np.random.randn(50).tolist()
y_scatter = np.random.randn(50).tolist()

fig = make_subplots(
    rows=3, cols=1,
    subplot_titles=("Line Plot: Random Data", "Bar Plot: Random Values", "Scatter Plot"),
)

fig.add_trace(go.Scatter(x=x_line.tolist(), y=y_line.tolist(), mode="lines",
                         name="Line Data", line=dict(color="blue", width=2)), row=1, col=1)
fig.add_trace(go.Bar(x=categories, y=values, name="Bar Data",
                     marker_color="green", opacity=0.7), row=2, col=1)
fig.add_trace(go.Scatter(x=x_scatter, y=y_scatter, mode="markers",
                         name="Scatter Data", marker=dict(color="red", size=6)), row=3, col=1)

fig.update_xaxes(title_text="X-axis", tickformat=".0f", row=1, col=1)
fig.update_yaxes(title_text="Values", tickformat=".0f", row=1, col=1)
fig.update_xaxes(title_text="Categories", row=2, col=1)
fig.update_yaxes(title_text="Values", tickformat=".1f", row=2, col=1)
fig.update_xaxes(title_text="X", tickformat=".1f", row=3, col=1)
fig.update_yaxes(title_text="Y", tickformat=".1f", row=3, col=1)

fig.update_layout(title="Multipanel Plot: Line, Bar, and Scatter", height=900, showlegend=False)

maidr.show(fig)
# Out:
# <iframe id="iframe_27e03a40-cc5a-40af-ba02-94ddcaec3bcc" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;4a85f5fc-4c3c-4c89-8219-891b24c59131&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:900px; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;4a85f5fc-4c3c-4c89-8219-891b24c59131&quo
# ...

# %% [markdown]
# ## 16. Facet Bar Plot (2x2 Grid)

# %%
categories = ["A", "B", "C", "D", "E"]
np.random.seed(42)
data_sets = [
    (np.random.rand(5) * 10).tolist(),
    (np.random.rand(5) * 100).tolist(),
    (np.random.rand(5) * 36).tolist(),
    (np.random.rand(5) * 42).tolist(),
]
condition_names = ["Group 1", "Group 2", "Group 3", "Group 4"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]

all_data = np.concatenate(data_sets)
y_min = float(np.min(all_data) * 0.9)
y_max = float(np.max(all_data) * 1.1)

fig = make_subplots(rows=2, cols=2, subplot_titles=tuple(condition_names),
                    shared_xaxes=True, shared_yaxes=True)

for i, (data, condition) in enumerate(zip(data_sets, condition_names)):
    row = i // 2 + 1
    col = i % 2 + 1
    fig.add_trace(
        go.Bar(x=categories, y=data, name=condition, marker_color=colors[i],
               opacity=0.7, text=[f"{v:.1f}" for v in data], textposition="outside"),
        row=row, col=col,
    )

for i in range(1, 5):
    yaxis_key = f"yaxis{i}" if i > 1 else "yaxis"
    fig.layout[yaxis_key].update(range=[y_min, y_max], tickformat=".1f")

fig.update_xaxes(title_text="Categories", row=2, col=1)
fig.update_xaxes(title_text="Categories", row=2, col=2)
fig.update_yaxes(title_text="Values", row=1, col=1)
fig.update_yaxes(title_text="Values", row=2, col=1)

fig.update_layout(title="Facet Plot: Bar Charts by Condition", height=700, showlegend=False)

maidr.show(fig)
# Out:
# <iframe id="iframe_576ab288-3afb-407c-afd2-63f6af730fbc" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;58ddf22b-4876-489c-9eb9-1bb522c6d9d9&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:700px; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;58ddf22b-4876-489c-9eb9-1bb522c6d9d9&quo
# ...

# %% [markdown]
# ## 17. Facet Combined Plot (Line + Bar)

# %%
num_rows = 3
num_points = 5
x = np.arange(num_points)
np.random.seed(42)
line_data = [np.random.rand(num_points) * 10 for _ in range(num_rows)]
bar_data = [np.abs(np.sin(x + i) * 5) + i for i in range(num_rows)]

subplot_titles = []
for r in range(1, num_rows + 1):
    subplot_titles.extend([f"Line Plot {r}", f"Bar Plot {r}"])

colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

fig = make_subplots(rows=num_rows, cols=2, subplot_titles=tuple(subplot_titles),
                    shared_yaxes="rows")

for row in range(num_rows):
    fig.add_trace(
        go.Scatter(x=x.tolist(), y=line_data[row].tolist(), mode="lines+markers",
                   name=f"Line {row + 1}", line=dict(color=colors[row], width=2),
                   marker=dict(size=6)),
        row=row + 1, col=1,
    )
    fig.add_trace(
        go.Bar(x=x.tolist(), y=bar_data[row].tolist(), name=f"Bar {row + 1}",
               marker_color=colors[row], opacity=0.7),
        row=row + 1, col=2,
    )
    fig.update_yaxes(title_text=f"Values (Row {row + 1})", tickformat=".1f",
                     row=row + 1, col=1)
    fig.update_yaxes(tickformat=".1f", row=row + 1, col=2)

fig.update_xaxes(title_text="X Values", tickformat=".0f", row=num_rows, col=1)
fig.update_xaxes(title_text="X Values", tickformat=".0f", row=num_rows, col=2)

fig.update_layout(title="Facet Plot Example with Shared Y-Axes",
                  height=300 * num_rows, showlegend=False)

maidr.show(fig)
# Out:
# <iframe id="iframe_feb40fd9-019a-432d-b81f-d60799921bba" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;div&gt;&lt;div&gt;                        &lt;script type=&quot;text/javascript&quot;&gt;window.PlotlyConfig = {MathJaxConfig: &apos;local&apos;};&lt;/script&gt;&#10;        &lt;script charset=&quot;utf-8&quot; src=&quot;https://cdn.plot.ly/plotly-3.3.1.min.js&quot; integrity=&quot;sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;                &lt;div id=&quot;ae978901-c29e-4b7d-9453-f33995751fb2&quot; class=&quot;plotly-graph-div&quot; style=&quot;height:900px; width:100%;&quot;&gt;&lt;/div&gt;            &lt;script type=&quot;text/javascript&quot;&gt;                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById(&quot;ae978901-c29e-4b7d-9453-f33995751fb2&quo
# ...

# %%
import mplfinance as mpf
import pandas as pd
import matplotlib.dates as mdates

import maidr 

# Load the sample data
daily = pd.read_csv("./example/candle_stick/volcandat.csv", index_col=0, parse_dates=True)

# Create the candlestick chart with moving averages and volume
fig, axlist = mpf.plot(
    daily,
    type="candle",
    volume=True,
    mav = (3,6,9),
    returnfig=True,
    ylabel="Price",
    ylabel_lower="Volume",
    xlabel="Date",
    title="Stock Price with Volume",
)  

# Add formatters for better screen reader output
# Price axis - Currency format
axlist[0].yaxis.set_major_formatter("${x:,.2f}")
# Date axis - Custom date format like "Nov 18, 2016"
axlist[0].xaxis.set_major_formatter(mdates.DateFormatter("%b %d, %Y"))
# Volume axis - Integer with thousands separator
axlist[2].yaxis.set_major_formatter("{x:,.0f}")

fig.tight_layout()

# Display with maidr
maidr.show(fig)
# Out:
# <iframe id="iframe_081ed0b8-2b82-41aa-b10c-a6cc6a9e55d7" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            (function() {&#10;                var existing = document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr.js&quot;]&apos;);&#10;                if (!existing) {&#10;                    var s = document.createElement(&apos;script&apos;);&#10;                    s.src = &apos;http://localhost:8888/tree/maidr.js&apos;;&#10;                    s.onload = function() { if (window.main) window.main(); };&#10;                    document.head.appendChild(s);&#10;                } else {&#10;                    if (document.readyState === &apos;loading&apos;) {&#10;                        document.addEventListener(&apos;DOMContentLoaded&apos;, function() { if (window.main) window.main(); });&#10;      
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import maidr 


# Load the 'tips' dataset from seaborn
tips = sns.load_dataset("tips") 

# Choose a specific subset of the dataset (e.g., data for 'Thursday')
subset_data = tips[tips["day"] == "Thur"]

# Create a line plot
fig, ax = plt.subplots(figsize=(6, 6))
line_plot = sns.lineplot( 
    data=subset_data,
    x="total_bill",
    y="tip",
    markers=True,
    style="day",
    legend=False,
    ax=ax,
)
ax.set_title("Tips vs Total Bill (Thursday)")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")

# Add currency formatters for better screen reader output
ax.xaxis.set_major_formatter("${x:.2f}")
ax.yaxis.set_major_formatter("${x:.2f}")

maidr.show(line_plot)
# Out:
# <iframe id="iframe_e5fffe8a-ef29-4774-ac6a-e070fa507ee1" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr@latest/dist/maidr_style.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            (function() {&#10;                var existing = document.querySelector(&apos;script[src=&quot;http://localhost:8888/tree/maidr.js&quot;]&apos;);&#10;                if (!existing) {&#10;                    var s = document.createElement(&apos;script&apos;);&#10;                    s.src = &apos;http://localhost:8888/tree/maidr.js&apos;;&#10;                    s.onload = function() { if (window.main) window.main(); };&#10;                    document.head.appendChild(s);&#10;                } else {&#10;                    if (document.readyState === &apos;loading&apos;) {&#10;                        document.addEventListener(&apos;DOMContentLoaded&apos;, function() { if (window.main) window.main(); });&#10;      
# ...
