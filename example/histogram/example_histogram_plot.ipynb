# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: <object object at 0x10587f5a0>

# %%
import maidr
import matplotlib.pyplot as plt
import seaborn as sns


# Load the dataset
iris = sns.load_dataset("iris")

# Choose a column for the histogram, for example, the 'petal_length'
data = iris["petal_length"]

# Create the histogram plot
_, _, hist_plot = plt.hist(data, bins=20, edgecolor="black")
plt.title("Histogram of Petal Lengths in Iris Dataset")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")

# plt.show()
maidr.show(hist_plot)
# Out:
# <iframe id="iframe_08b5db78-1bdf-49be-b513-48c13ea552ed" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;ffa621b9-5e96-46f2-8eab-57e81704d0d1&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;3ede4872-3552-4407-bb82-e0ac7152d070&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;8ca023db-4797-4d9f-8421-1fb7d24c3b5b&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;hist&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Histogram of Petal Lengths in Iris Dataset&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Petal Length (cm)&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Frequency&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 4.0,&amp;#10;                &amp;quot;x&amp;quot;: 1.1475,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.0,&amp;#10;                &amp;quot;xMax&amp;quot;: 1.295,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 4.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 33.0,&amp;#10;                &amp;quot;x&amp;quot;: 1.4425,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.295,&amp;#10;                &amp;quot;xMax&amp;quot;: 1.59,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 33.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 11.0,&amp;#10;                &amp;quot;x&amp;quot;: 1.7375000000000003,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.5900000000000003,&amp;#10;                &amp;quot;xMax&amp;quot;: 1.8850000000000005,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 11.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 2.0,&amp;#10;                &amp;quot;x&amp;quot;: 2.0325,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.8850000000000002,&amp;#10;                &amp;quot;xMax&amp;quot;: 2.18,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 2.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 0.0,&amp;#10;                &amp;quot;x&amp;quot;: 2.3275,&amp;#10;                &amp;quot;xMin&amp;quot;: 2.18,&amp;#10;                &amp;quot;xMax&amp;quot;: 2.475,&amp;#10;                &amp;quot;yMin&amp;quot ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")

# Select the petal lengths
petal_lengths = iris["petal_length"]

# Plot a histogram of the petal lengths
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(petal_lengths, kde=True, color="blue", binwidth=0.5)

plt.title("Histogram of Petal Lengths in Iris Dataset")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequency")

# plt.show()
maidr.show(hist_plot)
# Out:
# <iframe id="iframe_351d7bd3-cc77-4e57-80aa-5cda8c36e307" srcdoc="&lt;div&gt;&#10;  &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;  &lt;script type=&quot;text/javascript&quot;&gt;&#10;            if (!document.querySelector(&apos;script[src=&quot;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&quot;]&apos;))&#10;            {&#10;                var script = document.createElement(&apos;script&apos;);&#10;                script.type = &apos;module&apos;;&#10;                script.src = &apos;https://cdn.jsdelivr.net/npm/maidr-ts/dist/maidr.js&apos;;&#10;                script.addEventListener(&apos;load&apos;, function() {&#10;                    window.main();&#10;                });&#10;                document.head.appendChild(script);&#10;            } else {&#10;                document.addEventListener(&apos;DOMContentLoaded&apos;, function (e) {&#10;                    window.main();&#10;                });&#10;            }&#10;        &lt;/script&gt;&#10;  &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;720pt&quot; height=&quot;432pt&quot; viewBox=&quot;0 0 720 432&quot; version=&quot;1.1&quot; id=&quot;d782e696-bcb2-42b7-86a3-0323492a2d0c&quot; maidr-data=&quot;{&amp;#10;  &amp;quot;id&amp;quot;: &amp;quot;b6382077-7998-4022-87fc-4df03cf0ec7f&amp;quot;,&amp;#10;  &amp;quot;subplots&amp;quot;: [&amp;#10;    [&amp;#10;      {&amp;#10;        &amp;quot;id&amp;quot;: &amp;quot;67facc99-0ede-4cb3-9beb-3e7413e631f4&amp;quot;,&amp;#10;        &amp;quot;layers&amp;quot;: [&amp;#10;          {&amp;#10;            &amp;quot;type&amp;quot;: &amp;quot;hist&amp;quot;,&amp;#10;            &amp;quot;title&amp;quot;: &amp;quot;Histogram of Petal Lengths in Iris Dataset&amp;quot;,&amp;#10;            &amp;quot;axes&amp;quot;: {&amp;#10;              &amp;quot;x&amp;quot;: &amp;quot;Petal Length (cm)&amp;quot;,&amp;#10;              &amp;quot;y&amp;quot;: &amp;quot;Frequency&amp;quot;&amp;#10;            },&amp;#10;            &amp;quot;data&amp;quot;: [&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 24.0,&amp;#10;                &amp;quot;x&amp;quot;: 1.2458333333333333,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.0,&amp;#10;                &amp;quot;xMax&amp;quot;: 1.4916666666666667,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 24.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 26.0,&amp;#10;                &amp;quot;x&amp;quot;: 1.7375,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.4916666666666667,&amp;#10;                &amp;quot;xMax&amp;quot;: 1.9833333333333334,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 26.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 0.0,&amp;#10;                &amp;quot;x&amp;quot;: 2.229166666666667,&amp;#10;                &amp;quot;xMin&amp;quot;: 1.9833333333333336,&amp;#10;                &amp;quot;xMax&amp;quot;: 2.4750000000000005,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 0.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 0.0,&amp;#10;                &amp;quot;x&amp;quot;: 2.720833333333333,&amp;#10;                &amp;quot;xMin&amp;quot;: 2.4749999999999996,&amp;#10;                &amp;quot;xMax&amp;quot;: 2.9666666666666663,&amp;#10;                &amp;quot;yMin&amp;quot;: 0,&amp;#10;                &amp;quot;yMax&amp;quot;: 0.0&amp;#10;              },&amp;#10;              {&amp;#10;                &amp;quot;y&amp;quot;: 3.0,&amp;#10;                &amp;quot;x&amp;quot;: 3.2125000000000004,&amp;#10;                &amp;quot;xMin&amp;quot;: 2.966666666666667,&amp;#10;    ...
